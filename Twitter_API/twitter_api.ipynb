# %%
#import tweepy -> $ pip install tweepy
#git clone https://github.com/tweepy/tweepy.git
#cd tweepy
#pip install .
import tweepy
#import configparser -> $ pip install configparser (to grab information from config file, safty) 
import configparser
#import pandas -> $ pip install pandas (to export to CSV file) 
import pandas as pd

# %%
#read the config file
config = configparser.ConfigParser()
config.read('config.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

#print(API_KEY_SECRET)

# %%
#authentication -> authenticate api/account to the twitter api
#pip3 show tweepy
from tweepy.auth import OAuthHandler
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
# create the api instance to authenticate our app
api = tweepy.API(auth)

# %%
#to access public tweets on your personal account
#public_tweets = api.home_timeline()
#print out all public tweets on your personal account
#print(public_tweets)

#print out the first public tweets(text) on your personal account
#print(public_tweets[0].text)

#print every public tweets(text) on your personal account
#for tweet in public_tweets:
    #print(tweet.text)

# %%
#columns = ['Time', 'User', 'Tweet']
#data = []

#for tweet in public_tweets:
 #   data.append([tweet.created_at, tweet.user.screen_name, tweet.text])

#df = pd.DataFrame(data, columns=columns)

#print(data)
#print(df)

#df.to_csv('tweets.csv')

# %%
#get user tweets
#specify which user
user = 'ncdhhs'
#uptain n tweets
limit = 10


#read the tweets
#tweet_mode = 'extended' -> specify not 100 characters
#api only return at max 200 tweets per request 
#tweets = api.user_timeline(screen_name = user, count = limit, tweet_mode = 'extended')

#tweepy.Cursor
#200 -> max amount
#tweets = tweepy.Cursor(api.user_timeline, screen_name = user, count = 200, tweet_mode = 'extended').items(limit)


#for tweet in tweets:
 #   print(tweet.full_text)

# %%
#get tweets
# can include # or @ 
keywords = '#COVID-19'
limit = 5000
date_since = "2022-01-01"


#read the tweets
#tweet_mode = 'extended' -> specify not 100 characters
#api only return at max 200 tweets per request 
#tweets = api.search_tweets(q = keywords, count = limit, tweet_mode = 'extended')

#tweepy.Cursor
#100 -> max amount
covid_tweets = tweepy.Cursor(api.search_tweets, q = keywords, count = 100, lang = "en", since = date_since, tweet_mode = 'extended').items(limit)

#for tweet in covid_tweets:
 #  print(tweet)

COVID19_tweets_columns = ['author_id', 'created_at_date', 'user_id', 'user_name','user_screen_name','user_location','user_url','id','text','retweet_count']
COVID19_tweets_data = []

#for tweet in covid_tweets:
 #   COVID19_tweets_data.append([tweet.author.id, tweet.created_at ,tweet.user.id, tweet.user.name, tweet.user.screen_name, tweet.user.location, tweet.user.url, tweet.id, tweet.full_text, tweet.retweet_count])
    #print([tweet.author.id, tweet.user.id, tweet.user.name, tweet.user.screen_name, tweet.user.location, tweet.user.url, tweet.id, tweet.full_text, tweet.retweet_count])
  #  print([tweet.created_at])

df = pd.DataFrame(COVID19_tweets_data, columns=COVID19_tweets_columns)

#print(COVID19_tweets_data)
#print(df)

df.to_csv('covid_tweets_5000.csv')
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# [datetime.datetime(2022, 5, 11, 19, 11, 55, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 54, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 53, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 53, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 53, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 52, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 51, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 50, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 49, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 48, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 48, tzinfo=datetime.timezone.utc)]
# [datetime.datetime(2022, 5, 11, 19, 11, 46, tzinfo=datetime.timezone.utc)]
# ...
